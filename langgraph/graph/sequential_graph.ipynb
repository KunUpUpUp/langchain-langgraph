# %%
from langgraph.graph import StateGraph
from typing import TypedDict
from IPython.display import Image, display

# %%
class SeqAgent(TypedDict):
    name: str
    result: str

# %%
def first_node(state: SeqAgent) -> SeqAgent:
    state["result"] = f'Hello {state["name"]}'
    return state

# %%
def second_node(state: SeqAgent) -> SeqAgent:
    state["result"] += f', your name is {state["name"]}'
    # state["result"] = state["result"] + f', your name is {state["name"]}'
    return state

# %%
graph = StateGraph(SeqAgent)

graph.add_node("first_node", first_node)
graph.add_node("second_node", second_node)

graph.set_entry_point("first_node")
graph.add_edge("first_node", "second_node")
graph.set_finish_point("second_node")
app = graph.compile()

# %%
result = app.invoke({"name": "zkp"})

# %%
result
# Out:
# {'name': 'zkp', 'result': 'Hello zkp, your name is zkp'}
